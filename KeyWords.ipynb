# %%
from nltk.tokenize import RegexpTokenizer
from stop_words import get_stop_words
from nltk.stem.porter import PorterStemmer
import pandas as pd
import os
from string import punctuation
from sklearn.feature_extraction.text import TfidfVectorizer
from gensim import corpora
import gensim
import spacy
import nltk
from nltk.corpus import stopwords
from spacy import displacy

# %%
def load_data(path = r"D:\NLP\dataset"):
    document_files = os.listdir(path)
    doc = [[""]] * len(document_files)
    i = 0
    for document in document_files:
        with open(path + "/" + document, "r") as f:
            doc[i] = f.read()
        i += 1
    return doc

# %%
def deal_data(doc):
    news_df = pd.DataFrame({'document': doc})
    # removing everything except alphabets`
    news_df['clean_doc'] = news_df['document'].str.replace("[^a-zA-Z#]", " ")
    # removing short words
    news_df['clean_doc'] = news_df['clean_doc'].apply(lambda x: ' '.join([w for w in x.split() if len(w) > 3]))
    # make all text lowercase
    news_df['clean_doc'] = news_df['clean_doc'].apply(lambda x: x.lower())
    nltk.download('stopwords')
    stop_words = stopwords.words('english')
    # tokenization
    tokenized_doc = news_df['clean_doc'].apply(lambda x: x.split())
    # remove stop-words
    tokenized_doc = tokenized_doc.apply(lambda x: [item for item in x if item not in stop_words])
    detokenized_doc = []
    for i in range(len(news_df)):
        t = ' '.join(tokenized_doc[i])
        detokenized_doc.append(t)
    tokenizer = RegexpTokenizer(r'\w+')
    # create English stop words list
    en_stop = get_stop_words('en')
    # Create p_stemmer of class PorterStemmer
    p_stemmer = PorterStemmer()
    # compile sample documents into a list
    # list for tokenized documents in loop
    texts = []
    for i in detokenized_doc:
        # clean and tokenize document string
        raw = i.lower()
        tokens = tokenizer.tokenize(raw)
        # remove stop words from tokens
        stopped_tokens = [i for i in tokens if not i in en_stop]
        # stem tokens
        stemmed_tokens = [p_stemmer.stem(i) for i in stopped_tokens]
        # add tokens to list
        texts.append(stemmed_tokens)
    return texts

# %%
class KeyWord():
    def __init__(self,method,num_keywords):
        self.method=method
        self.num_keywords=num_keywords
    def LSA(self,texts,num_keywords):
        detokenized_doc = []
        for i in range(len(texts)):
            t = ' '.join(texts[i])
            detokenized_doc.append(t)
        news_df=pd.DataFrame()
        news_df['clean_doc'] = detokenized_doc
        vectorizer = TfidfVectorizer(stop_words='english', max_features=1000, smooth_idf=True)
        X = vectorizer.fit_transform(news_df['clean_doc'])
        from sklearn.decomposition import TruncatedSVD
        # SVD represent documents and terms in vectors
        svd_model = TruncatedSVD(n_components=20, algorithm='randomized', n_iter=100, random_state=122)
        svd_model.fit(X)
        terms = vectorizer.get_feature_names()
        for i, comp in enumerate(svd_model.components_):
            terms_comp = zip(terms, comp)
            sorted_terms = sorted(terms_comp, key=lambda x: x[1], reverse=True)[:num_keywords]
            print("text " + str(i) + "'s keyword: ")
            for t in sorted_terms:
                print(t[0])
                print(" ")
    def LDA(self,texts,num_keywords):
        dictionary = corpora.Dictionary(texts)

        # convert tokenized documents into a document-term matrix
        corpus = [dictionary.doc2bow(text) for text in texts]
        # generate LDA model
        ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics=5, id2word=dictionary, passes=30)
        print(ldamodel.print_topics(num_topics=5, num_words=num_keywords))
    def spacy1(self,data):
        a=len(data)
        nlp = spacy.load("en_core_web_sm")
        for i in range(a):
            result=self.extract_keywords(nlp,data[i])
            print("text"+str(i)+"'s keyword:")
            print(result)
    def extract_keywords(self,nlp, sequence, special_tags: list = None):
        result = []
        # edit this list of POS tags according to your needs.
        pos_tag = ['PROPN', 'NOUN', 'ADJ']
        doc = nlp(sequence.lower())
        if special_tags:
            tags = [tag.lower() for tag in special_tags]
            for token in doc:
                if token.text in tags:
                    result.append(token.text)
        for chunk in doc.noun_chunks:
            final_chunk = ""
            for token in chunk:
                if (token.pos_ in pos_tag):
                    final_chunk = final_chunk + token.text + " "
            if final_chunk:
                result.append(final_chunk.strip())
        for token in doc:
            if (token.text in nlp.Defaults.stop_words or token.text in punctuation):
                continue
            if (token.pos_ in pos_tag):
                result.append(token.text)
        return list(set(result))
    def spacy2(self,doc):
        for ent in doc.ents:
            print(ent.text, ent.label_)
        displacy.render(doc, style='ent', jupyter=True)
    def fit(self):
        if self.method=='LSA':
            doc=load_data()
            data=deal_data(doc)
            self.LSA(data,num_keywords=self.num_keywords)
        if self.method=='LDA':
            doc = load_data()
            data = deal_data(doc)
            self.LDA(data,num_keywords=self.num_keywords)
        if self.method=='spacy1':
            data=load_data()
            self.spacy1(data)
        if self.method=='spacy2':
            nlp = spacy.load("en_core_web_sm")
            data=load_data()
            a = len(data)
            for i in range(a):
                doc = nlp(data[i].lower())
                print("text" + str(i) + "'s keyword:")
                self.spacy2(doc)

# %%
if __name__ == '__main__':
    model=KeyWord(method='LSA',num_keywords=20)
    model.fit()
# Out:
# text 0's keyword:
# women
#
# matern
#
# month
#
# said
#
# hewitt
#
# plan
#
# paid
#
# sexism
#
# elect
#
# cost
#
# extend
#
# work
#
# leav
#
# week
#
# career
#
# job
#
# mother
#
# brown
#
# labour
#
# rise
#
# text 1's keyword:
# blackpool
#
# mail
#
# inform
#
# parti
#
# manchest
#
# ball
#
# confer
#
# labour
#
# brown
#
# rule
#
# chancellor
#
# delet
#
# freedom
#
# elect
#
# host
#
# hotel
#
# said
#
# spend
#
# stabil
#
# come
#
# text 2's keyword:
# mail
#
# inform
#
# delet
#
# freedom
#
# thoma
#
# beith
#
# commission
#
# disclosur
#
# law
#
# public
#
# record
#
# said
#
# cabinet
#
# clear
#
# condemn
#
# destroy
#
# destruct
#
# forc
#
# guidanc
#
# offic
#
# text 3's keyword:
# ball
#
# brown
#
# elect
#
# spend
#
# stabil
#
# chancellor
#
# rise
#
# britain
#
# digbi
#
# rate
#
# spree
#
# think
#
# budget
#
# alli
#
# away
#
# cash
#
# econom
#
# economi
#
# expect
#
# jone
#
# text 4's keyword:
# matern
#
# week
#
# month
#
# plan
#
# democrat
#
# liber
#
# mother
#
# alreadi
#
# said
#
# allow
#
# children
#
# desper
#
# entitl
#
# father
#
# firm
#
# misdirect
#
# older
#
# parent
#
# extend
#
# right
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Angelo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
model=KeyWord(method='LDA',num_keywords=20)
model.fit()
# Out:
# [(0, '0.002*"said" + 0.002*"women" + 0.002*"elect" + 0.002*"labour" + 0.002*"month" + 0.002*"mail" + 0.002*"hewitt" + 0.002*"work" + 0.002*"paid" + 0.002*"plan" + 0.002*"brown" + 0.002*"parti" + 0.002*"inform" + 0.002*"sexism" + 0.002*"told" + 0.002*"govern" + 0.002*"matern" + 0.002*"extend" + 0.002*"rule" + 0.002*"cost"'), (1, '0.002*"said" + 0.002*"mail" + 0.002*"inform" + 0.002*"freedom" + 0.002*"thoma" + 0.002*"time" + 0.002*"record" + 0.002*"commission" + 0.002*"rule" + 0.002*"public" + 0.002*"delet" + 0.002*"beith" + 0.002*"disclosur" + 0.002*"cabinet" + 0.002*"govern" + 0.002*"prevent" + 0.002*"come" + 0.002*"import" + 0.002*"condemn" + 0.002*"destruct"'), (2, '0.028*"said" + 0.018*"elect" + 0.017*"month" + 0.017*"matern" + 0.015*"brown" + 0.011*"labour" + 0.011*"plan" + 0.011*"ball" + 0.011*"rise" + 0.009*"chancellor" + 0.008*"mother" + 0.008*"right" + 0.008*"week" + 0.008*"stabil" + 0.008*"budget" + 0.008*"spend" + 0.008*"extend" + 0.008*"extra" + 0.008*"cost" + 0.008*"hewitt"'), (3, '0.029*"women" + 0.017*"work" + 0.017*"blackpool" + 0.014*"parti" + 0.012*"sexism" + 0.010*"hewitt" + 0.010*"job" + 0.010*"manchest" + 0.010*"career" + 0.010*"labour" + 0.010*"said" + 0.008*"month" + 0.008*"cost" + 0.008*"full" + 0.008*"time" + 0.008*"paid" + 0.008*"year" + 0.008*"confer" + 0.006*"trade" + 0.006*"industri"'), (4, '0.034*"mail" + 0.031*"inform" + 0.024*"said" + 0.017*"delet" + 0.017*"freedom" + 0.014*"thoma" + 0.011*"rule" + 0.011*"time" + 0.011*"public" + 0.011*"record" + 0.011*"law" + 0.011*"disclosur" + 0.011*"beith" + 0.011*"commission" + 0.007*"tori" + 0.007*"govern" + 0.007*"come" + 0.007*"import" + 0.007*"subject" + 0.007*"order"')]
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Angelo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
model=KeyWord(method='spacy1',num_keywords=20)
model.fit()
# Out:
# text0's keyword:
# ['gidley', 'liberal', 'money', 'government statutory pay', 'liberal democrat spokeswoman', 'small', 'brown', 'length', 'average', 'salary costs', 'shadow', 'budget', 'period', 'children', 'advertising costs', 'end', 'working', 'first months', 'plans', 'months', 'recruitment costs', 'gordon brown', 'labour', 'gordon', 'majority', 'shadow secretary', 'many women', 'parliament', 'flexible', 'democrat', 'earnings', 'women voters', 'gmtv', 'plan', 'employers', 'bid', 'democrats', 'baby', 'family', 'new proposals', 'parents', 'many small firms', 'director general', 'strain', 'other proposals', 'proposals', '%', 'maternity pay plan', 'maternity', 'weeks', 'pre - budget review', 'firm commitment', 'maternity pay', 'general', 'gmtv sunday programme', 'details', 'firms', 'average earnings', 'mothers', 'firm', 'aim', 'recruitment', 'labour plans', 'crippled', 'desperate', 'frost', 'party', 'old', 'first weeks', 'fathers', 'tony blair', 'patricia', 'government', 'extra', 'full months', 'blair', 'commitment', 'pay', 'time', 'older children', 'other plans', 'next parliament', 'week', 'conservatives', 'chambers', 'monday', 'rise', 'trade', 'liberal democrats', 'tony', 'women sandra gidley', 'statutory', 'carers', 'desperate bid', 'sunday', 'taxpayers', 'tories', 'government plans', 'review', 'december', 'flexible working', 'move', 'birth', 'salary', 'secretary', 'programme', 'home', 'david frost', 'election', 'part', 'more women', 'theresa', 'trade industry secretary patricia hewitt', 'new', 'costs', 'ms', 'new mothers', 'hewitt', 'director', 'industry', 'british chambers', 'commerce', 'women', 'sandra', 'david', 'state', 'voters', 'further details', 'ms hewitt', 'british', 'ministers', 'spokeswoman', 'advertising', 'company', 'general election', 'partner', 'older', 'pre', 'theresa may', 'rights']
# text1's keyword:
# ['further use', 'next year', 'same time', 'key', 'deletions', 'e - mail deletions', 'cabinet office spokeswoman', 'criminal', 'information commissioner', 'scotland', 'chairman', 'alan', 'unlikely', 'information', 'thing', 'later disclosure', 'cabinet', 'e - mail regime', 'tory', 'lib dems', 'constitutional', 'wales', 'affairs', 'mr thomas', 'record', 'e - mail retention', 'months', 'important thing', 'freedom', 'hutton', 'orders', 'parliament', 'force', 'probes', 'northern', 'beith', 'forces', 'civil', 'government guidance', 'deliberate', 'commissioner', 'chancellor', 'key probes', 'mr beith', 'timing', 'subject', 'authorities', 'details', 'staff', 'deliberate destruction', 'clear', 'implementation', 'disclosure', 'civil service', 'watchdog probes', 'order', 'legitimate', 'public', 'lord chancellor', 'information regime', 'hutton inquiry', 'information act', 'records', 'similar measures', 'measures', 'clear guidance', 'act', 'michael', 'richard', 'tory leader michael howard', 'old', 'various exemptions', 'service', 'tony blair', 'government', 'thomas', 'mails', 'blair', 'content', 'richard thomas', 'time', 'monday', 'use', 'tony', 'retention', 'explanation', 'committee', 'england', 'code', 'leader', 'e mails', 'inquiry', 'tories', 'important', 'government e mails', 'deletion', 'new laws', 'lib', 'millions', 'information laws', 'exemptions', 'e - mail', 'move', 'new act', 'doubt', 'watchdog', 'current', 'howard', 'regime', 'january', 'ability', 'access', 'office', 'laws', 'right', 'dems', 'e', 'lib dem constitutional affairs committee chairman alan beith', 'principle', 'rules', 'new', 'guidance', 'retain', 'important records', 'destruction', 'particular record', 'public authorities', 'mr', 'dem', 'lord', 'criminal offence', 'ireland', 'coincidence', 'practice', 'possibility', 'public bodies', 'year', 'current purpose', 'spokeswoman', 'cabinet office orders', 'mail', 'new rules', 'bodies', 'purpose', 'northern ireland', 'later', 'similar', 'offence', 'particular']
# text2's keyword:
# ['potential', 'payment', 'pound', 'gender pay gap', 'labour election manifesto', 'full time', 'taster courses', 'gender productivity seminar', 'police', 'leave', 'average', 'instance', 'gap', 'priority', 'future', 'hundreds', 'appropriate', 'positions', 'period', 'non', 'unions', 'decries', 'ftse companies', 'first months', 'woman', 'plans', 'ideas', 'employees', 'months', 'equal wage policies', 'average woman', 'labour', 'stereotypical', 'ages', 'opportunities', 'female science engineering graduates', 'male sectors', 'fashioned', '80p', 'employers', 'trade industry secretary', 'natural', 'companies', 'cost', 'goal', 'sexes', 'worse', 'vital', 'grounds', 'employment', 'second', 'proposals', '%', 'maternity', 'result', 'radio', 'progress', 'experts', 'universities', 'high priority', 'manifesto', 'full time work', 'courses', 'sex', 'cases', 'prominent', 'counterparts', 'old fashioned stereotypical ideas', 'mothers', 'tuc', 'pay gap', 'ways', 'work', 'eoc', 'britons', 'today programme', 'department', 'jobs', 'pay figures', 'traditional', 'income', 'drive', 'career', 'childcare jobs', 'old', 'male counterparts', 'suitable', 'engineering', 'judiciary trade unions', 'patricia', 'government', 'science', 'taxpayer', 'high', 'delegates', 'pay', 'bbc', 'appropriate jobs', 'wrong', 'implications', 'job', 'commission', 'time', 'less %', 'construction', 'panel', 'trade', 'judiciary', 'patricia hewitt', 'months leave', 'research', 'sexism', 'second months', 'gender', 'top positions', 'new pay experts panel', 'equal opportunities commission', 'male industry', 'maternity leave', 'unpaid', 'secretary', 'election', 'programme', 'fact', 'full potential', 'natural differences', 'productivity', 'seminar', 'new drive', 'female', 'policies', 'new', 'bbc radio', 'ms', 'taster', 'equal', 'man', 'figures', 'things', 'career sexism', 'hewitt', 'minister', 'differences', 'industry', 'women', 'today', 'men', '60p', 'ftse', 'hewitt decries career sexism', 'non - traditional jobs', 'childcare', 'graduates', 'cost implications', 'funding', 'year', 'ms hewitt', 'wage', 'male', 'sectors', 'many britons']
# text3's keyword:
# ['smaller', 'annual event', 'asplin', 'year deal', 'autumn', 'major manchester hotels', 'country', 'larger', 'working', 'main working class resort', 'conference', 'spring', 'labour', 'smaller february spring conference', 'placatory move', 'political', 'blackpool', 'traditional choice', 'class party', 'coastal', 'cost', 'autumn conference', 'hotel', 'larger annual conference', 'deal', 'class', 'official announcement', 'annual', 'exact', 'major', 'main', 'parties', 'labour national executive committee', 'traditional', 'resort', 'executive', 'seaside', 'party', 'sure', 'decision', 'hotel accommodation', 'following year bournemouth', 'exact cost', 'seaside venue', 'main political parties', 'bookings', 'choice', 'blow', 'accommodation', 'blackpool hotel association', 'time', 'block bookings', 'brighton', 'national', 'committee', 'announcement', 'venue', 'terms', 'break', 'first time', 'block', 'event', 'years', 'labour party', 'bournemouth', 'crowds', 'coastal resort', 'chooses', 'february', 'following', 'manchester', 'revenue', 'news', 'placatory', 'year', 'official', 'hotels', 'colin', 'association']
# text4's keyword:
# ['house', 'margin', 'prospective labour mp', 'rate rise', 'key', 'polling', 'golden', 'fiscal rules', 'brown', 'mr brown', 'cbi', 'pace', 'budget', 'way', 'golden economic rule', 'brown ally', 'pundits', 'adviser', 'jones', 'big', 'ex - chief economic adviser', 'record', 'mpc', 'pre - election spending spree', 'third term', 'big election issue', 'gordon brown', 'labour', 'gordon', 'boring stability', 'most pundits', 'political', 'fiscal', 'priorities', 'message', 'bank', 'pre - election bribes', 'pre', 'speculation', 'extra cash', 'foreign secretary', 'labour candidate', 'change', 'chancellor', 'radio', 'successful', 'house prices', 'parliamentary lunch', 'labour party chances', 'conservative', 'policy', 'general', 'rate', 'parliamentary', 'issue', 'interest rates', 'successful labour government', 'monetary', 'good', 'prices', 'bribes', 'date', 'risk', 'interview', 'economy', 'workers skills', 'sir digby jones', 'political culture', 'mp', 'chancellor gordon brown closest ally', 'rates', 'public', 'ex', 'business', 'expectations', 'prime', 'may', 'budget giveaway', 'prospective', 'party', 'sure', 'sir digby', 'britain', 'excess', 'prudent chancellor', 'sir', 'government', 'workers', 'mr brown budget', 'extra', 'people', 'blair', 'cbi director general', 'term', 'bbc', 'job', 'credit', 'ally', 'spending', 'chances', 'rise', 'polling day', 'form', 'cash', 'tony', 'committee', 'chief', 'england', 'post', 'public spending', 'culture', 'ed balls', 'competitiveness', 'strength', 'important', 'conservative party', 'interest', 'key word british business', 'current', 'closest', 'programme', 'january', 'election', 'secretary', 'digby', 'assurances', 'part', 'word', 'candidate', 'right', 'near record pace', 'ed', 'giveaway', 'near', 'balls', 'consumer', 'good way', 'suggestions', 'rules', 'lunch', 'current tax credit rules', 'economic', 'figures', 'treasury post', 'mr balls', 'minister', 'director', 'march', 'mr', 'rule', 'bbc radio today programme', 'stability', 'today', 'confident', 'treasury', 'foreign', 'skills', 'british', 'day', 'prime minister tony blair', 'spree', 'tax', 'boring', 'budget spree', 'consumer borrowing', 'prudent', 'big change', 'borrowing']

# %%
model=KeyWord(method='spacy2',num_keywords=20)
model.fit()
# Out:
# text0's keyword:
# labour ORG
# patricia hewitt PERSON
# nine months by 2007 DATE
# gmtv PERSON
# sunday DATE
# democrats NORP
# 13 weeks DATE
# up to 26 weeks DATE
# nine months by 2007 DATE
# the full 12 months DATE
# 12 months DATE
# six CARDINAL
# the six months DATE
# nine months DATE
# gordon brown PERSON
# december DATE
# tony blair PERSON
# conservatives NORP
# democrat NORP
# sandra gidley PERSON
# democrats NORP
# the first six months DATE
# david frost PERSON
# british NORP
# commerce ORG
# monday DATE
# 90% PERCENT
# the first six weeks DATE
# a week DATE
# six months old DATE
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     labour
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  plans maternity pay rise</br></br>maternity pay for new mothers is to rise by 拢1,400 as part of new proposals announced by the trade and industry secretary
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     patricia hewitt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# .</br></br>it would mean paid leave would be increased to
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nine months by 2007
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , ms hewitt told
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     gmtv
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# 's
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sunday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  programme. other plans include letting maternity pay be given to fathers and extending rights to parents of older children. the tories dismissed the maternity pay plan as &quot;desperate&quot;, while the liberal
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     democrats
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  said it was misdirected.</br></br>ms hewitt said: &quot;we have already doubled the length of maternity pay, it was
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     13 weeks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  when we were elected, we have already taken it
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     up to 26 weeks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . &quot;we are going to extend the pay to
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nine months by 2007
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and the aim is to get it right up to
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the full 12 months
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  by the end of the next parliament.&quot; she said new mothers were already entitled to
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     12 months
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  leave, but that many women could not take it as only
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     six
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of those months were paid. &quot;we have made a firm commitment. we will definitely extend the maternity pay, from
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the six months
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  where it now is to
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nine months
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , that's the extra 拢1,400.&quot; she said ministers would consult on other proposals that could see fathers being allowed to take some of their partner's maternity pay or leave period, or extending the rights of flexible working to carers or parents of older children. the shadow secretary of state for the family, theresa may, said: &quot;these plans were announced by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     gordon brown
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  in his pre-budget review in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     december
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tony blair
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is now recycling it in his desperate bid to win back women voters.&quot;</br></br>she said the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     conservatives
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  would announce their proposals closer to the general election. liberal
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     democrat
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  spokeswoman for women
# <mark
# text1's keyword:
# watchdog ORG
# delete e-mails PERSON
# more than three months old DATE
# richard thomas PERSON
# 1 january DATE
# thomas PERSON
# tories NORP
# michael howard PERSON
# tony blair PERSON
# monday DATE
# lib dem constitutional affairs committee ORG
# alan beith PERSON
# millions CARDINAL
# hutton ORG
# thomas PERSON
# the new act of parliament LAW
# thomas PERSON
# england GPE
# wales GPE
# northern ireland GPE
# next year DATE
# scotland GPE
# about 100,000 CARDINAL
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     watchdog
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  probes e-mail deletions</br></br>the information commissioner says he is urgently asking for details of cabinet office orders telling staff to
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     delete e-mails
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     more than three months old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .</br></br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     richard thomas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  &quot;totally condemned&quot; the deletion of e-mails to prevent their disclosure under freedom of information laws coming into force on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1 january
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . government guidance said e-mails should only be deleted if they served &quot;no current purpose&quot;, mr
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     thomas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said. the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tories
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  and the lib dems have questioned the timing of the new rules.</br></br>tory leader
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     michael howard
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  has written to
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tony blair
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  demanding an explanation of the new rules on e-mail retention. on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     lib dem constitutional affairs committee
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  chairman
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     alan beith
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  warned that the deletion of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     millions
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of government e-mails could harm the ability of key probes like the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hutton
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  inquiry. the timing of the new rules just before the freedom of information act comes into forces was &quot;too unlikely to have been a coincidence&quot;, mr beith said. but a cabinet office spokeswoman said the move was not about the new laws or &quot;the destruction of important records&quot;. mr beith urged the information commissioner to look at how the &quot;e-mail regime&quot; could &quot;support the freedom of information regime&quot;.</br></br>mr
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     thomas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said: &quot;
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the new act of parliament
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LAW</span>
# </mark>
#  makes it very clear that to destroy records in order to prevent their disclosure becomes a criminal offence.&quot; he said there was already clear guidance on the retention of e-mails contained in a code of practice from the lord chancellor. all e-mails are subject to the freedom of information laws, but the important thing was the content of the e-mail, said mr
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     thomas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# .</br></br>&quot;if in doubt retain, that has been the long-standing principle of the civil service and public authorities. it's only when you've got no further use for the particular record that it may be legitimate to destroy it. &quot;but any deliberate destruction to avoid the possibility of later disclosure is to be totally condemned.&quot; the freedom of information act will cover
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     england
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle
# text2's keyword:
# six months DATE
# patricia hewitt PERSON
# the equal opportunities commission ORG
# eoc ORG
# up to six months' DATE
# six CARDINAL
# the first six months DATE
# the second six months DATE
# 19% PERCENT
# bbc radio 4's ORG
# today DATE
# about six CARDINAL
# 20 CARDINAL
# only 10% PERCENT
# about 80p CARDINAL
# 60p DATE
# the department for trade and industry ORG
# hundreds CARDINAL
# last year DATE
# less than 10% PERCENT
# 100 CARDINAL
# just over half CARDINAL
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">hewitt decries 'career sexism'</br></br>plans to extend paid maternity leave beyond
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     six months
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  should be prominent in labour's election manifesto, the trade and industry secretary has said.</br></br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     patricia hewitt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said the cost of the proposals was being evaluated, but it was an &quot;increasingly high priority&quot; and a &quot;shared goal across government&quot;. ms hewitt was speaking at a gender and productivity seminar organised by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the equal opportunities commission
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     eoc
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ). mothers can currently take
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     up to six months'
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  paid leave - and
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     six
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  unpaid. ms hewitt told the seminar: &quot;clearly, one of the things we need to do in the future is to extend the period of payment for maternity leave beyond
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the first six months
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  into
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the second six months
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . &quot;we are looking at how quickly we can do that, because obviously there are cost implications because the taxpayer reimburses the employers for the cost of that.&quot;</br></br>ms hewitt also announced a new drive to help women who want to work in male dominated sectors, saying sexism at work was still preventing women reaching their full potential. plans include funding for universities to help female science and engineering graduates find jobs and &quot;taster courses&quot; for men and women in non-traditional jobs. women in full-time work earn
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     19%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  less than men, according to the equal opportunities commission (eoc).</br></br>the minister told delegates that getting rid of &quot;career sexism&quot; was vital to closing the gender pay gap.</br></br>&quot;career sexism limits opportunities for women of all ages and prevents them from achieving their full potential. &quot;it is simply wrong to assume someone cannot do a job on the grounds of their sex,&quot; she said. earlier, she told
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bbc radio 4's
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  programme: &quot;what we are talking about here is the fact that
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     about six
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  out of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     20
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  women work in jobs that are low-paid and typically dominated by women, so we have got very segregated employment. &quot;unfortunately, in some cases, this reflects very old-fashioned and stereotypical ideas about the appropriate jobs for women, or indeed for men. &quot;career sexism is about saying that engineering, for instance, where
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     only 10%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  of employees are women, is really a male-dominated industry. construction is even worse. &quot;but it is also about saying childcare jobs are really there for women and not suitable for men. career sexism goes both ways.&quot;</br></br>she added that while progress had been made, there was still a gap in pay figures. &quot;the average woman working full-time is being paid
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     about 80p
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  for every pound a man is earning. for women working part-time it is
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     60p
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .&quot;
# <mark class="entity" style="background: #7aecec; padding
# text3's keyword:
# manchester
#
#  PERSON
# the labour party ORG
# 2006 DATE
# national executive committee ORG
# first ORDINAL
# 1917 DATE
# annual DATE
# february spring DATE
# years DATE
# bournemouth PERSON
# brighton GPE
# annual DATE
# 1998 DATE
# 2002 DATE
# the following year bournemouth DATE
# two year DATE
# blackpool hotel association ORG
# the labour party ORG
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">labour chooses
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     manchester
#
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the labour party
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  will hold its
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2006
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  autumn conference in manchester and not blackpool, it has been confirmed.</br></br>the much trailed decision was ratified by labour's ruling
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     national executive committee
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in a break with the traditional choice of a seaside venue. it will be the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  time since
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1917
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  that the party has chosen manchester to host the
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     annual
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  event. blackpool will get the much smaller
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     february spring
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  conference instead in what will be seen as a placatory move.</br></br>for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  the main political parties have rotated between blackpool,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bournemouth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     brighton
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . and the news the much larger
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     annual
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  conference is not to gather in blackpool will be seen as a blow in the coastal resort. in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1998
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  the party said it would not return to blackpool but did so in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2002
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the following year bournemouth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  hosted the event before the party signed a
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  deal for brighton to host the autumn conference.</br></br>colin asplin,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     blackpool hotel association
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  said: &quot;we have tried very hard to make sure they come back to blackpool. &quot;obviously we have failed in that. i just hope manchester can handle the crowds. &quot;it amazes me that
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the labour party
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , which is a working class party, doesn't want to come to the main working class resort in the country.&quot; the exact cost to blackpool in terms of lost revenue for hotel accommodation is not yet known but it is thought that block bookings will be taken at the major manchester hotels after the official announcement.</br></div></span>
# text4's keyword:
# brown PERSON
# gordon brown's PERSON
# 16 march DATE
# treasury ORG
# balls PERSON
# digby jones PERSON
# cbi ORG
# balls PERSON
# treasury ORG
# brown PERSON
# the labour party's ORG
# january DATE
# the bank of england's ORG
# monetary policy committee ORG
# britain GPE
# bbc radio 4's ORG
# today DATE
# balls PERSON
# brown PERSON
# 2001 DATE
# british NORP
# britain GPE
# balls PERSON
# brown PERSON
# gordon brown PERSON
# third ORDINAL
# britain GPE
# balls PERSON
# today DATE
# tony blair PERSON
# 5 CARDINAL
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     brown
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  ally rejects budget spree</br></br>chancellor
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     gordon brown's
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  closest ally has denied suggestions there will be a budget giveaway on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     16 march
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .</br></br>ed balls, ex-chief economic adviser to the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     treasury
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , said there would be no spending spree before polling day. but mr
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     balls
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , a prospective labour mp, said he was confident the chancellor would meet his fiscal rules. he was speaking as sir
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     digby jones
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cbi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  director general, warned mr brown not to be tempted to use any extra cash on pre-election bribes.</br></br>mr
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     balls
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , who stepped down from his
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     treasury
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  post to stand as a labour candidate in the election, had suggested that mr
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     brown
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  would meet his golden economic rule - &quot;with a margin to spare&quot;. he said he hoped more would be done to build on current tax credit rules.</br></br>he also stressed rise in interest rates ahead of an expected may election would not affect
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the labour party's
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  chances of winning. expectations of a rate rise have gathered pace after figures showed house prices are still rising. consumer borrowing rose at a near-record pace in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     january
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . &quot;if the mpc (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the bank of england's
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     monetary policy committee
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) were to judge that a rate rise was justified before the election because of the strength of the economy - and i'm not predicting that they will - i do not believe that this will be a big election issue in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     britain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  for labour,&quot; he told a parliamentary lunch. &quot;this is a big change in our political culture.&quot;</br></br>during an interview with
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bbc radio 4's
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  programme, mr
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     balls
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said he was sure mr
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     brown
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# 's budget would not put at risk the stability of the economy. &quot;i don't think we'll see a pre-election spending spree - we certainly did not see that before
# <mark class="entity" style="background: #bf
