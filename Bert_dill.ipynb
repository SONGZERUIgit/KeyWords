# %% [markdown]
# <a href="https://colab.research.google.com/github/SONGZERUIgit/KeyWords/blob/main/Bert_dill.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd '/content/drive/My Drive'
# Out:
# /content/drive/My Drive

# %%
#!mkdir researchHub
#os.chdir('./researchHub')

# %%
#!git clone https://github.com/ahoho/kd-topic-models.git
# Out:
# Cloning into 'kd-topic-models'...
# remote: Enumerating objects: 94, done.
# remote: Counting objects: 100% (94/94), done.
# remote: Compressing objects: 100% (71/71), done.
# remote: Total 94 (delta 20), reused 81 (delta 14), pack-reused 0
# Unpacking objects: 100% (94/94), done.

# %%
# !ls
# Out:
#  2020年度总结.gdoc			   意大利1.gdoc
# 'Colab Notebooks'			   意大利2.gdoc
#  DAC光谱到波长光谱.gslides		   报告.gdoc
#  ES4M_s278848.gdoc			  '无标题文档 (1).gdoc'
#  inbound2691320485739591320.jpg		  '无标题文档 (2).gdoc'
#  lab1-2.gdoc				  '无标题文档 (3).gdoc'
# 'MBSD Assignment_SONGZERUI_S278848.gdoc'  '无标题文档 (4).gdoc'
#  MBSD_EXAM_20210209.gdoc		  '无标题文档 (5).gdoc'
#  MBSD_exam.gdoc				  '无标题文档 (6).gdoc'
#  MBSD_EXAM_SONGZERUI.gdoc		   无标题文档.gdoc
#  MBSD_Lab_SONGZERUI_S278848.gdoc	  '无标题电子表格 (1).gsheet'
# 'OSES ASSIGNMENT ON RTOS.gdoc'		   无标题电子表格.gsheet
#  PSP.gdoc				   硬件系统标准.gdoc
#  researchHub				  '简历 (1).gdoc'
# 'Self activity.gdoc'			   简历.gdoc
#  Template.gslides			   简历_szr.gdoc
#  互联网计算广告笔记.gdoc		   简历_宋.gdoc
#  五一旅行计划（暂定）.gsheet		  '简历_宋泽芮 (1).gdoc'
#  体温登记表.gdoc			  '简历_宋泽芮 (1).pdf'
#  光学实验平台清单.gsheet		   简历_宋泽芮.gdoc
#  待办事项列表.gsheet

# %%
# Out:
# /content/drive/My Drive/researchHub/researchHub/kd-topic-models

# %%
# !which python
# Out:
# /usr/local/bin/python

# %%
# !python --version
# Out:
# Python 3.7.10

# %%
# !echo $PYTHONPATH
# Out:
# /env/python

# %%
# %env PYTHONPATH=
# Out:
# env: PYTHONPATH=

# %%
# %%bash
# MINICONDA_INSTALLER_SCRIPT=Miniconda3-4.5.4-Linux-x86_64.sh
# MINICONDA_PREFIX=/usr/local
# wget https://repo.continuum.io/miniconda/$MINICONDA_INSTALLER_SCRIPT
# chmod +x $MINICONDA_INSTALLER_SCRIPT
# ./$MINICONDA_INSTALLER_SCRIPT -b -f -p $MINICONDA_PREFIX
# Out:
# PREFIX=/usr/local
# installing: python-3.6.5-hc3d631a_2 ...
# installing: ca-certificates-2018.03.07-0 ...
# installing: conda-env-2.6.0-h36134e3_1 ...
# installing: libgcc-ng-7.2.0-hdf63c60_3 ...
# installing: libstdcxx-ng-7.2.0-hdf63c60_3 ...
# installing: libffi-3.2.1-hd88cf55_4 ...
# installing: ncurses-6.1-hf484d3e_0 ...
# installing: openssl-1.0.2o-h20670df_0 ...
# installing: tk-8.6.7-hc745277_3 ...
# installing: xz-5.2.4-h14c3975_4 ...
# installing: yaml-0.1.7-had09818_2 ...
# installing: zlib-1.2.11-ha838bed_2 ...
# installing: libedit-3.1.20170329-h6b74fdf_2 ...
# installing: readline-7.0-ha6073c6_4 ...
# installing: sqlite-3.23.1-he433501_0 ...
# installing: asn1crypto-0.24.0-py36_0 ...
# installing: certifi-2018.4.16-py36_0 ...
# installing: chardet-3.0.4-py36h0f667ec_1 ...
# installing: idna-2.6-py36h82fb2a8_1 ...
# installing: pycosat-0.6.3-py36h0a5515d_0 ...
# installing: pycparser-2.18-py36hf9f622e_1 ...
# installing: pysocks-1.6.8-py36_0 ...
# ...

# %%
# !which python
# Out:
# /usr/local/bin/python

# %%
# !python --version
# Out:
# Python 3.6.5 :: Anaconda, Inc.

# %%
# %%bash
# conda install --channel defaults conda python=3.6 --yes
# conda update --channel defaults --all --yes
# Out:
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#     - python=3.6
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     pyopenssl-20.0.1           |     pyhd3eb1b0_1          48 KB
#     libgcc-ng-9.1.0            |       hdf63c60_0         8.1 MB
#     zlib-1.2.11                |       h7b6447c_3         120 KB
#     cffi-1.14.5                |   py36h261ae71_0         224 KB
#     ncurses-6.2                |       he6710b0_1         1.1 MB
#     cryptography-3.4.7         |   py36hd23ed53_0         1.0 MB
#     urllib3-1.26.6             |     pyhd3eb1b0_1         106 KB
#     _libgcc_mutex-0.1          |             main           3 KB
#     python-3.6.13              |       h12debd9_1        32.5 MB
#     wheel-0.36.2               |     pyhd3eb1b0_0          31 KB
# ...

# %%
# !ls /usr/local/lib/python3.6/dist-packages

# %%
import sys
_ = (sys.path
        .append("/usr/local/lib/python3.6/site-packages"))

# %%
# %cd '/content/drive/My Drive/researchHub/researchHub/kd-topic-models'
# Out:
# /content/drive/My Drive/researchHub/researchHub/kd-topic-models

# %%
# !conda env create -f scholar/scholar.yml
# Out:
# done
# done
#
# ...
# wcwidth-0.1.7        | 22 KB     | : 100% 1.0/1 [00:00<00:00,  9.00it/s]
# pexpect-4.7.0        | 80 KB     | : 100% 1.0/1 [00:00<00:00,  5.56it/s]
# zstd-1.3.7           | 401 KB    | : 100% 1.0/1 [00:00<00:00, 10.02it/s]
# tornado-6.0.3        | 584 KB    | : 100% 1.0/1 [00:00<00:00,  3.62it/s]
# murmurhash-1.0.2     | 27 KB     | : 100% 1.0/1 [00:00<00:00,  5.99it/s]
# pytorch-1.2.0        | 428.0 MB  | : 100% 1.0/1 [01:09<00:00, 69.90s/it]
# pycparser-2.19       | 171 KB    | : 100% 1.0/1 [00:00<00:00, 13.03it/s]
# tk-8.6.8             | 2.8 MB    | : 100% 1.0/1 [00:00<00:00,  5.50it/s]
# asn1crypto-1.2.0     | 166 KB    | : 100% 1.0/1 [00:00<00:00,  3.73it/s]
# backcall-0.1.0       | 20 KB     | : 100% 1.0/1 [00:00<00:00, 16.51it/s]
# intel-openmp-2019.4  | 729 KB    | : 100% 1.0/1 [00:00<00:00,  9.12it/s]
# entrypoints-0.3      | 12 KB     | : 100% 1.0/1 [00:00<00:00, 12.87it/s]
# zipp-0.6.0           | 9 KB      | : 100% 1.0/1 [00:00<00:00, 13.00it/s]
# ...

# %%
# !conda env create -f teacher/teacher.yml
# Out:
# done
# done
#
# ...
# lazy-object-proxy-1. | 36 KB     | : 100% 1.0/1 [00:00<00:00,  5.40it/s]
# mkl_random-1.1.0     | 340 KB    | : 100% 1.0/1 [00:00<00:00,  4.04it/s]
# libprotobuf-3.11.4   | 4.8 MB    | : 100% 1.0/1 [00:01<00:00,  1.14s/it]
# ptyprocess-0.6.0     | 23 KB     | : 100% 1.0/1 [00:00<00:00,  4.28it/s]
# blas-1.0             | 1 KB      | : 100% 1.0/1 [00:00<00:00, 22.87it/s]
# ninja-1.9.0          | 1.2 MB    | : 100% 1.0/1 [00:00<00:00,  1.25it/s]
# wcwidth-0.1.9        | 23 KB     | : 100% 1.0/1 [00:00<00:00,  4.09it/s]
# tensorboardx-2.0     | 77 KB     | : 100% 1.0/1 [00:00<00:00,  6.47it/s]
# numpy-base-1.18.1    | 4.2 MB    | : 100% 1.0/1 [00:00<00:00,  1.12it/s]
# python_abi-3.8       | 4 KB      | : 100% 1.0/1 [00:00<00:00, 27.60it/s]
# backcall-0.1.0       | 21 KB     | : 100% 1.0/1 [00:00<00:00,  4.38it/s]
# python-3.8.2         | 49.6 MB   | : 100% 1.0/1 [00:01<00:00,  1.65s/it]
# astroid-2.3.3        | 287 KB    | : 100% 1.0/1 [00:00<00:00,  4.42it/s]
# ...

# %%
# %%bash
# source activate scholar
# python data/imdb/download_imdb.py
#
# # main preprocessing script

# %%
# %%bash
# source activate scholar
#
# python data/imdb/preprocess_data.py data/imdb/train.jsonlist data/imdb/processed --vocab-size 5000 --test data/imdb/test.jsonlist
# Out:
# Using snowball stopwords
# Reading data files
# Found 25000 training documents
# Found 25000 test documents
# Parsing documents
# Train set processing complete
# Test set processing complete
# Size of full vocabulary=117981
# Selecting the vocabulary
# Vocab size after filtering = 117981
# Final vocab size = 5000
# Most common words remaining: movie one film like just good time even see really
# Converting to count representations
# Size of train document-term matrix: (25000, 5000)
# Converting to count representations
# Size of test document-term matrix: (25000, 5000)
# 0 words missing from training data
# 0 words missing from test data
# Done!

# %%
# !ls
# Out:
# analysis.ipynb	Miniconda3-4.5.4-Linux-x86_64.sh  README.md  stopwords	w-lda
# data		processed-dev			  scholar    teacher

# %%
# %cd  './data/imdb'
# Out:
# /content/drive/My Drive/researchHub/researchHub/kd-topic-models/data/imdb

# %%
# %%bash
#
# source activate scholar
# python create_dev_split.py

# %%
# %cd '../..'
# Out:
# /content/drive/My Drive/researchHub/researchHub/kd-topic-models

# %%
# %%bash
#
# source activate transformers28
# python teacher/bert_reconstruction.py --help

# %%
# %%bash
#
# source activate transformers28
#
# python teacher/bert_reconstruction.py  \
# --input-dir='./data/imdb/processed-dev' \
# --output-dir='./data/imdb/processed-dev/logits'\
# Out:
# 2021-07-06 09:11:31 - transformers.tokenization_utils -   loading file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-vocab.txt from cache at /root/.cache/torch/transformers/26bc1ad6c0ac742e9b52263248f6d0f00068293b33709fae12320c0e35ccfbbb.542ce4285a40d23a559526243235df47c5f75c197f04f37d1a0c124c32c9a084
# 2021-07-06 09:11:31 - __main__ -   Loading and tokenizing data
# 2021-07-06 09:14:31 - transformers.configuration_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 2021-07-06 09:14:31 - transformers.configuration_utils -   Model config BertConfig {
#   "_num_labels": 5000,
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bad_words_ids": null,
#   "bos_token_id": null,
# ...
